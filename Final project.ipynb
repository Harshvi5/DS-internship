# %%
#Name :Harshvi Sangela
#Roll no :27
#College :Keystone School of Engineering

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('exercise.csv')

# %%
total_entries = df.shape[0]

# %%
print("Total number of entries in the dataset:", total_entries)
# Out:
# Total number of entries in the dataset: 90

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='pulse', hue='diet', kde=True, bins=30)
plt.title('Distribution of Resting Heart Rates by Diet Type')
plt.xlabel('Resting Heart Rate')
plt.ylabel('Frequency')
plt.legend(title='Diet Type')
plt.grid(True)
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
heart_rates = ['pulse_before_exercise', 'pulse_after_exercise']

# %%
#3]
plt.figure(figsize=(12, 6))

for diet_type in df['diet'].unique():
    diet_df = df[df['diet'] == diet_type]
    sns.histplot(data=diet_df, x='pulse', hue='kind', kde=True, bins=30, label=diet_type)

plt.title('Distribution of Heart Rates Before and After Exercise by Diet Type')
plt.xlabel('Heart Rate')
plt.ylabel('Frequency')
plt.legend(title='Diet Type')

plt.tight_layout()
plt.show()

# %%
#4.Calculate the average heart rate by diet type and activity level.

average_heart_rate = df.groupby(['diet', 'kind'])['pulse'].mean()
print(average_heart_rate)
# Out:
# diet     kind
# low fat  rest        89.333333
#          running    105.066667
#          walking     93.466667
# no fat   rest        92.333333
#          running    121.066667
#          walking     96.933333
# Name: pulse, dtype: float64

# %%
#5.Calculate average heart rate by diet type and activity level.

average_heart_rate = df.groupby(['diet', 'kind'])['pulse'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=average_heart_rate, x='diet', y='pulse', hue='kind')
plt.title('Average Heart Rate by Diet Type and Activity Level')
plt.xlabel('Diet Type')
plt.ylabel('Average Heart Rate')
plt.legend(title='Activity Level')
plt.show()

# %%
###6.Print the names of individuals with the highest and lowest heart rates after exercise
# Theres no column name "names" in the given dataset.

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
#7. Plot the distribution of heart rates before and after exercise by gender.

plt.figure(figsize=(12, 6))

# Before Exercise
plt.subplot(1, 2, 1)
sns.boxplot(x='diet', y='pulse', hue='time', data=df[df['time'] == '1 min'])
plt.title('Heart Rate Before Exercise')

# After Exercise
plt.subplot(1, 2, 2)
sns.boxplot(x='diet', y='pulse', hue='time', data=df[df['time'] == '30 min'])
plt.title('Heart Rate After Exercise')

plt.tight_layout()
plt.show()

# %%
#8. Calculate the median heart rate for each activity level.
median_heart_rate_by_activity = df.groupby('kind')['pulse'].median()

print(median_heart_rate_by_activity)
# Out:
# kind
# rest        91.5
# running    110.0
# walking     95.5
# Name: pulse, dtype: float64

# %%
#####9. Print the names of individuals with the highest and lowest heart rate differences between before and after exercise.
# Theres no column name "names" in the given dataset.

# %%
#10.Plot the distribution of heart rate differences between before and after exercise by diet type
# Plotting
plt.figure(figsize=(10, 6))
sns.boxplot(x='diet', y='heart_rate_difference', data=df)
plt.title('Distribution of Heart Rate Differences by Diet Type')
plt.xlabel('Diet Type')
plt.ylabel('Heart Rate Difference (After Exercise - Before Exercise)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 #10.Plot the distribution of heart rate differences between before and after exercise by diet type
#       2 # Plotting
#       3 plt.figure(figsize=(10, 6))
# ----> 4 sns.boxplot(x='diet', y='heart_rate_difference', data=df)
#       5 plt.title('Distribution of Heart Rate Differences by Diet Type')
#       6 plt.xlabel('Diet Type')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
# ...
